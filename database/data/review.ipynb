# %%
import pandas as pd
data = pd.read_csv('diem_thi_thpt_2024.csv')

# %%
foreign_ids = data['ma_ngoai_ngu'].dropna().unique()
foreign_ids
# Out:
# array(['N1', 'N3', 'N6', 'N7', 'N5', 'N4', 'N2'], dtype=object)

# %%
for _, row in data.iterrows():
	# make sure to check if the value is not NaN
	if pd.notna(row['ma_ngoai_ngu']):
		print(row['ma_ngoai_ngu'])
# Out:
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N3
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N6
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N7
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N7
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N5
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N7
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# N1
# ...
